# %%
import log_regres
# %matplotlib inline

# %%
log_regres.plot_best_fit()
# Out:
# start cost: [0.71144676]
# end cost after 500 epoches: 0.19438156

# %%
error_rate = log_regres.colicTest()
# Out:
# start cost: [1.0333774]
# end cost after 10000 epoches: 1.106501
# the error rate of this test is: 25.37%
